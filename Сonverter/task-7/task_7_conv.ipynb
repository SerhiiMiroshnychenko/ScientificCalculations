# %% [markdown]
# # Задача 7: Розрахунок питомої теплоємності залізної руди
#
# ## Умова задачі
# Визначити питому теплоємність залізної руди наступного хімічного складу, мас. %:
# - Fe₂O₃ – 34,1
# - H₂O – 7,5
# - порожня порода (SiO₂) – 58,4
#
# Теплоємність компонентів, кДж/(кг·°С):
# - Fe₂O₃ – 0,61
# - H₂O – 4,2
# - порожня порода (SiO₂) – 1,17
#
# ## Теоретичні відомості
#
# Для суміші речовин питома теплоємність визначається за правилом адитивності:
#
# $$ c = \sum_{i=1}^n x_i c_i $$
#
# де:
# - $c$ - питома теплоємність суміші
# - $x_i$ - масова частка i-го компонента (в десятковому вигляді)
# - $c_i$ - питома теплоємність i-го компонента
#
# ## Розв'язання
#
# ### 1. Переведення масових часток у десятковий вигляд
# - Fe₂O₃: $x_1 = 34,1\% = 0,341$
# - H₂O: $x_2 = 7,5\% = 0,075$
# - SiO₂: $x_3 = 58,4\% = 0,584$
#
# ### 2. Розрахунок питомої теплоємності суміші
#
# $$ c = 0,341 \cdot 0,61 + 0,075 \cdot 4,2 + 0,584 \cdot 1,17 $$
#
# $$ c = 0,20801 + 0,315 + 0,68328 $$
#
# $$ c = 1,20629 \text{ кДж/(кг·°С)} $$
#
# ### 3. Перевірка розмірностей
# - Масові частки: [безрозмірні]
# - Теплоємності компонентів: [кДж/(кг·°С)]
# - Результат: [кДж/(кг·°С)]
#
# ### 4. Перевірка суми масових часток
# $$ x_1 + x_2 + x_3 = 0,341 + 0,075 + 0,584 = 1,000 $$
#
# ### 5. Переведення в одиниці SI
# В системі SI теплоємність вимірюється в Дж/(кг·К).
# Оскільки:
# - 1 кДж = 1000 Дж
# - 1°С = 1 К (для різниці температур)
#
# $$ c_{SI} = 1,20629 \cdot 1000 = 1206,29 \text{ Дж/(кг·К)} $$
#
# ## Відповідь
# Питома теплоємність залізної руди становить 1206,29 Дж/(кг·К).
#
# ## Перевірка достовірності результату
# 1. Результат знаходиться в межах теплоємностей компонентів (0,61 - 4,2 кДж/(кг·°С))
# 2. Сума масових часток дорівнює 1
# 3. Розмірності збережені та переведені в SI

# %%
# Вхідні дані
# Масові частки компонентів, %
x_fe2o3 = 34.1  # Fe2O3
x_h2o = 7.5     # H2O
x_sio2 = 58.4   # SiO2 (порожня порода)

# Теплоємності компонентів, кДж/(кг·°С)
c_fe2o3 = 0.61  # Fe2O3
c_h2o = 4.2     # H2O
c_sio2 = 1.17   # SiO2

print("1. Вхідні дані:")
print("   Масові частки компонентів, %:")
print(f"   Fe2O3: {x_fe2o3}")
print(f"   H2O: {x_h2o}")
print(f"   SiO2: {x_sio2}")
print("\n   Теплоємності компонентів, кДж/(кг·°С):")
print(f"   Fe2O3: {c_fe2o3}")
print(f"   H2O: {c_h2o}")
print(f"   SiO2: {c_sio2}")
# Out:
# 1. Вхідні дані:
#    Масові частки компонентів, %:
#    Fe2O3: 34.1
#    H2O: 7.5
#    SiO2: 58.4
#
#    Теплоємності компонентів, кДж/(кг·°С):
#    Fe2O3: 0.61
#    H2O: 4.2
#    SiO2: 1.17

# %%
# Переведення масових часток у десятковий вигляд
x_fe2o3_dec = x_fe2o3/100
x_h2o_dec = x_h2o/100
x_sio2_dec = x_sio2/100

print("\n2. Масові частки у десятковому вигляді:")
print(f"   Fe2O3: {x_fe2o3_dec:.4f}")
print(f"   H2O: {x_h2o_dec:.4f}")
print(f"   SiO2: {x_sio2_dec:.4f}")
# Out:
# 2. Масові частки у десятковому вигляді:
#    Fe2O3: 0.3410
#    H2O: 0.0750
#    SiO2: 0.5840

# %%
# Перевірка суми масових часток
x_sum = x_fe2o3_dec + x_h2o_dec + x_sio2_dec
print(f"\n3. Сума масових часток: {x_sum:.4f}")
# Out:
# 3. Сума масових часток: 1.0000

# %%
# Розрахунок питомої теплоємності суміші
c_mix = x_fe2o3_dec * c_fe2o3 + x_h2o_dec * c_h2o + x_sio2_dec * c_sio2

print("\n4. Внески компонентів у теплоємність суміші, кДж/(кг·°С):")
print(f"   Fe2O3: {x_fe2o3_dec * c_fe2o3:.5f}")
print(f"   H2O: {x_h2o_dec * c_h2o:.5f}")
print(f"   SiO2: {x_sio2_dec * c_sio2:.5f}")

print(f"\n5. Питома теплоємність суміші:")
print(f"   c = {c_mix:.5f} кДж/(кг·°С)")
# Out:
# 4. Внески компонентів у теплоємність суміші, кДж/(кг·°С):
#    Fe2O3: 0.20801
#    H2O: 0.31500
#    SiO2: 0.68328
#
# 5. Питома теплоємність суміші:
#    c = 1.20629 кДж/(кг·°С)

# %%
# Переведення в одиниці SI
c_mix_SI = c_mix * 1000  # кДж -> Дж

print("\n6. Питома теплоємність в одиницях SI:")
print(f"   c = {c_mix_SI:.2f} Дж/(кг·К)")
# Out:
# 6. Питома теплоємність в одиницях SI:
#    c = 1206.29 Дж/(кг·К)

# %%
print("\n7. Перевірка достовірності:")
print(f"   - Результат в межах теплоємностей компонентів ({min(c_fe2o3, c_h2o, c_sio2)} - {max(c_fe2o3, c_h2o, c_sio2)} кДж/(кг·°С)): {'✓' if min(c_fe2o3, c_h2o, c_sio2) <= c_mix <= max(c_fe2o3, c_h2o, c_sio2) else '✗'}")
print(f"   - Сума масових часток = 1: {'✓' if abs(x_sum - 1) < 1e-10 else '✗'}")
print(f"   - Розмірності збережені та переведені в SI: ✓")
# Out:
# 7. Перевірка достовірності:
#    - Результат в межах теплоємностей компонентів (0.61 - 4.2 кДж/(кг·°С)): ✓
#    - Сума масових часток = 1: ✓
#    - Розмірності збережені та переведені в SI: ✓
